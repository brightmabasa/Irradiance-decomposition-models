# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load the data from the CSV file
df = pd.read_csv('STEL_GHIc_metrics_results.csv')

# Handle NaN, infinity, or large values in the dataset
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)


#import io
# Read the data into a pandas DataFrame
#df = pd.read_csv(io.StringIO(data), sep='\t')

# %%
# Calculate the absolute value of MBE
df['|MBE|'] = df['MBE'].abs()

# Rank the data based on |MBE|, MAE, and RMSE
df['Rank_MBE'] = df['|MBE|'].rank()
df['Rank_MAE'] = df['MAE'].rank()
df['Rank_RMSE'] = df['RMSE'].rank()

# Calculate the mean rank for each row
df['Mean_Rank'] = df[['Rank_MBE', 'Rank_MAE', 'Rank_RMSE']].mean(axis=1)

# Sort the DataFrame by Mean_Rank
df_sorted = df.sort_values(by='Mean_Rank')

# Select relevant columns for display and include model name
df_sorted.insert(0, 'Model', df_sorted.index)

# Round off the results to 2 decimal digits
df_sorted = df_sorted.round(2)

# Add a numeric rank column based on Mean_Rank starting from 1
df_sorted['Numeric_Rank'] = df_sorted['Mean_Rank'].rank(method='min').astype(int)
df['Numeric_Rank']= df_sorted['Numeric_Rank']

# Save the results to a CSV file
#df_sorted.to_csv('ranking_results.csv', index=False)

# Display the DataFrame with model names and rankings
#print(df_sorted[['Model', '|MBE|', 'MAE', 'RMSE', 'Rank_MBE', 'Rank_MAE', 'Rank_RMSE', 'Mean_Rank', 'Numeric_Rank']])
df_sorted
# Out:
#     Model         Unnamed: 0     MBE   rMBE    RMSE  rRMSE    r2     MAE  \
# 0       0       Mabasa_GHIcs   -0.47  -0.07   18.00   2.59  0.99   13.60
# 13     13        ABCGM_GHIcs    0.25   0.04   18.83   2.71  0.99   14.02
# 8       8    HaurwitzM_GHIcs   -0.49  -0.07   21.80   3.14  0.99   17.01
# 22     22        ghi_McClear   11.30   1.62   20.14   2.90  0.99   15.63
# 1       1           SS_GHIcs   -9.29  -1.34   21.67   3.12  0.99   17.39
# 6       6      Schulze_GHIcs    7.47   1.07   22.24   3.20  0.99   17.64
# 11     11          KCM_GHIcs    6.89   0.99   26.52   3.81  0.99   22.22
# 21     21           TJ_GHIcs  -18.73  -2.69   29.13   4.19  0.98   22.91
# 9       9          BDM_GHIcs    2.43   0.35   36.74   5.28  0.98   31.53
# 17     17       Sharma_GHIcs  -20.77  -2.99   28.67   4.12  0.99   24.58
# 2       2           IP_GHIcs  -22.72  -3.27   29.80   4.29  0.98   25.44
# 7       7     Haurwitz_GHIcs  -26.07  -3.75   39.63   5.70  0.97   30.33
# 5       5  Brichambaut_GHIcs  -32.19  -4.63   37.12   5.34  0.98   33.50
# 4       4     BigaRosa_GHIcs  -34.91  -5.02   41.32   5.94  0.97   35.95
# 14     14           RS_GHIcs  -37.96  -5.46   52.98   7.62  0.95   40.43
# 18     18   ElMghouchi_GHIcs  -50.43  -7.25   54.60   7.85  0.95   50.80
# 15     15          DPP_GHIcs   59.07   8.49   68.14   9.80  0.92   59.65
# 16     16    YangWalsh_GHIcs  -67.10  -9.65   69.53  10.00  0.92   67.30
# 3       3           BD_GHIcs  -67.94  -9.77   87.70  12.61  0.86   70.24
# 19     19          HLJ_GHIcs  -75.10 -10.80   77.31  11.12  0.90   75.17
# 12     12         ABCG_GHIcs  -96.71 -13.91  105.05  15.11  0.81   96.71
# 10     10           KC_GHIcs -121.18 -17.43  136.09  19.57  0.67  121.18
# 20     20       FuRich_GHIcs -200.44 -28.83  206.14  29.65  0.25  200.44
#
#      rMAE   |MBE|  Rank_MBE  Rank_MAE  Rank_RMSE  Mean_Rank  Numeric_Rank
# 0    1.96    0.47       2.0       1.0        1.0       1.33             1
# 13   2.02    0.25       1.0       2.0        2.0       1.67             2
# 8    2.45    0.49       3.0       4.0        5.0       4.00             3
# 22   2.25   11.30       8.0       3.0        3.0       4.67             4
# 1    2.50    9.29       7.0       5.0        4.0       5.33             5
# 6    2.54    7.47       6.0       6.0        6.0       6.00             6
# 11   3.20    6.89       5.0       7.0        7.0       6.33             7
# 21   3.30   18.73       9.0       8.0        9.0       8.67             8
# 9    4.54    2.43       4.0      12.0       11.0       9.00             9
# 17   3.53   20.77      10.0       9.0        8.0       9.00             9
# 2    3.66   22.72      11.0      10.0       10.0      10.33            11
# 7    4.36   26.07      12.0      11.0       13.0      12.00            12
# 5    4.82   32.19      13.0      13.0       12.0      12.67            13
# 4    5.17   34.91      14.0      14.0       14.0      14.00            14
# 14   5.82   37.96      15.0      15.0       15.0      15.00            15
# 18   7.31   50.43      16.0      16.0       16.0      16.00            16
# 15   8.58   59.07      17.0      17.0       17.0      17.00            17
# 16   9.68   67.10      18.0      18.0       18.0      18.00            18
# 3   10.10   67.94      19.0      19.0       20.0      19.33            19
# 19  10.81   75.10      20.0      20.0       19.0      19.67            20
# 12  13.91   96.71      21.0      21.0       21.0      21.00            21
# 10  17.43  121.18      22.0      22.0       22.0      22.00            22
# 20  28.83  200.44      23.0      23.0       23.0      23.00            23

# %%
df = df.round(3)
df.to_csv('STEL_GHIc_FINAL_Ranking_Results.csv', index=False)
